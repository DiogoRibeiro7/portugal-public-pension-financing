# %% [markdown]
# # 02 — CGA data audit
#
# Audit CGA annual reports and public accounts before constructing any long-run series.

# %% [markdown]
# ## Research contract
#
# - Read only validated or explicitly provisional inputs.
# - Preserve source identifiers and accounting basis.
# - Do not silently interpolate historical gaps.
# - Write all derived evidence to CSV before manuscript use.
# - A failure to reproduce a published claim is a result, not an error to hide.

# %%
from pathlib import Path

ROOT = Path.cwd().resolve().parents[0] if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
print(f'Repository root candidate: {ROOT}')

# %%
OUTPUTS = ['data/interim/cga_annual_financing.csv', 'evidence/data_quality_registry.csv']
for output in OUTPUTS:
    print(output)
